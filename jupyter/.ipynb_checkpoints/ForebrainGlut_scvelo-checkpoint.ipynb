# %% [markdown]
# ##  Stochastic RNA velocity analysis of Forebrain Glut using scRNAvelo
#
# We use a stochastic version of the model for transcriptional dynamics used in velocyto (developed by the Linnarsson lab and Kharchenko Lab).
#
# RNA velocity reference https://www.nature.com/articles/s41586-018-0414-6 <br>
#
# Files needed: hgForebrainGlut.loom (will be downloaded automatically)

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:90% !important; }</style>"))
# %matplotlib inline

import scvelo as scv
scv.logging.print_version()
# Out:
# <style>.container { width:90% !important; }</style>
# Running scvelo 0.1.16 on 2019-02-27 21:02.

# %%
scv.settings.set_figure_params('scvelo')

# %% [markdown]
# ## Load and cleanup the data

# %%
adata = scv.read('data/ForebrainGlut/hgForebrainGlut.loom', cleanup=True, sparse=True, cache=True, 
                 backup_url='http://pklab.med.harvard.edu/velocyto/hgForebrainGlut/hgForebrainGlut.loom')
adata.var_names_make_unique()
# Out:
# ... 100%
# Variable names are not unique. To make them unique, call `.var_names_make_unique`.
# ... storing 'Chromosome' as categorical
# ... storing 'Strand' as categorical

# %%
scv.pp.show_proportions(adata)
scv.pp.cleanup(adata, clean='all')

adata
# Out:
# Abundance of ['spliced', 'unspliced', 'ambiguous']: [0.66 0.27 0.07]
# AnnData object with n_obs × n_vars = 1720 × 32738
#     layers: 'spliced', 'unspliced'

# %% [markdown]
# ## Preprocess the data

# %%
scv.pp.filter_and_normalize(adata, min_counts=20, min_counts_u=10, n_top_genes=4000)
# Out:
# Filtered out 21757 genes that are detected in less than 20 counts (spliced).
# Filtered out 2002 genes that are detected in less than 10 counts (unspliced).
# Normalized count data: X, spliced, unspliced.
# Logarithmized X.

# %%
scv.pp.moments(adata)
# Out:
# computing neighbors
#     finished (0:00:04.20) --> added to `.uns['neighbors']`
#     'distances', weighted adjacency matrix
#     'connectivities', weighted adjacency matrix
# computing moments based on connectivities
#     finished (0:00:00.55) --> added
#     'Ms' and 'Mu', moments of spliced/unspliced abundances (adata.layers)

# %% [markdown]
# ## Compute velocity and velocity graph

# %%
scv.tl.velocity(adata)
# Out:
# computing velocities
#     finished (0:00:00.37) --> added
#     'velocity', velocity vectors for each individual cell (adata.layers)

# %%
scv.tl.velocity_graph(adata)
# Out:
# computing velocity graph
#     finished (0:00:04.25) --> added
#     'velocity_graph', sparse matrix with cosine correlations (adata.uns)

# %% [markdown]
# ## Project the velocity graph onto an embedding

# %%
scv.tl.louvain(adata, resolution=.7, random_state=4)
scv.tl.velocity_embedding(adata, basis='pca')
# Out:
# computing velocity embedding
#     finished (0:00:00.43) --> added
#     'velocity_pca', embedded velocity vectors (adata.obsm)

# %% [markdown]
# ## Cluster and annotate the data

# %%
scv.pl.velocity_embedding(adata, basis='pca')

# %%
scv.tl.terminal_states(adata)
# Out:
# computing terminal states
#     identified 2 root cells and 2 end points
#     finished (0:00:00.10) --> added
#     'root_cells', root cells of Markov diffusion process (adata.obs)
#     'end_points', end points of Markov diffusion process (adata.obs)

# %%
scv.pl.velocity_embedding_grid(adata, basis='pca', color=['root', 'end'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-12-90417f1f5087> in <module>
# ----> 1 scv.pl.velocity_embedding_grid(adata, basis='pca', color=['root', 'end'])
#
# ~/anaconda3/envs/scanpy/lib/python3.6/site-packages/scvelo/plotting/velocity_embedding_grid.py in velocity_embedding_grid(adata, basis, vkey, density, smooth, min_mass, arrow_size, arrow_length, arrow_color, scale, autoscale, n_neighbors, X, V, X_grid, V_grid, principal_curve, color, use_raw, layer, color_map, colorbar, palette, size, alpha, perc, sort_order, groups, components, projection, legend_loc, legend_fontsize, legend_fontweight, right_margin, left_margin, xlabel, ylabel, title, fontsize, figsize, dpi, frameon, show, save, ax, ncols, **kwargs)
#     144                                         X_grid=None if len(vkeys) > 1 else X_grid,
#     145                                         V_grid=None if len(vkeys) > 1 else V_grid,
# --> 146                                         autoscale=False if len(vkeys) > 1 else autoscale, **scatter_kwargs, **kwargs)
#     147         savefig_or_show('' if basis is None else basis, dpi=dpi, save=save, show=show)
#     148         if not show: return ax
#
# ~/anaconda3/envs/scanpy/lib/python3.6/site-packages/scvelo/plotting/velocity_embedding_grid.py in velocity_embedding_grid(adata, basis, vkey, density, smooth, min_mass, arrow_size, arrow_length, arrow_color, scale, autoscale, n_neighbors, X, V, X_grid, V_grid, principal_curve, color, use_raw, layer, color_map, colorbar, palette, size, alpha, perc, sort_order, groups, components, projection, legend_loc, legend_fontsize, legend_fontweight, right_margin, left_margin, xlabel, ylabel, title, fontsize, figsize, dpi, frameon, show, save, ax, ncols, **kwargs)
#     165
#     166         size = 4 * default_size(adata) if size is None else size
# --> 167         ax = scatter(adata, layer=layer, color=color, size=size, title=title, ax=ax, zorder=0, **scatter_kwargs)
#     168
#     169         savefig_or_show('' if basis is None else basis, dpi=dpi, save=save, show=show)
#
# ~/anaconda3/envs/scanpy/lib/python3.6/site-packages/scvelo/plotting/scatter.py in scatter(adata, x, y, basis, vkey, color, use_raw, layer, color_map, colorbar, palette, size, alpha, perc, sort_order, groups, components, projection, legend_loc, legend_fontsize, legend_fontweight, right_margin, left_margin, xlabel, ylabel, title, fontsize, figsize, dpi, frameon, show, save, ax, zorder, ncols, **kwargs)
#      95
#      96             c = interpret_colorkey(adata, basis, color, perc) if basis in adata.var_names and color in adata.layers.keys() \
# ---> 97                 else interpret_colorkey(adata, color, layer, perc)
#      98
#      99             if layer is not None and 'velocity' in layer and isinstance(color, str) and color in adata.var_names:
#
# ~/anaconda3/envs/scanpy/lib/python3.6/site-packages/scvelo/plotting/utils.py in interpret_colorkey(adata, c, layer, perc)
#     137             c = c.A.flatten() if issparse(c) else c
#     138         else:
# --> 139             raise ValueError('color key is invalid! pass valid observation annotation or a gene name')
#     140         if perc is not None: c = clip(c, perc=perc)
#     141     elif len(np.array(c).flatten()) == adata.n_obs:  # continuous coloring
#
# ValueError: color key is invalid! pass valid observation annotation or a gene name

# %%
scv.pl.velocity(adata, basis='pca', var_names=["ELAVL4", "STMN2", "GRIA3"])
