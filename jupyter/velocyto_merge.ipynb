# %% [markdown]
# #  Merging multiple samples/lanes in a single file
#
# The pipeline gives an introduction to the basic steps of merging multiple loom files into a single file.

# %% [markdown]
# ### Velocyto Loom
#
# Setup the environment

# %%
import os
import loompy
path="/Users/yah2014/Dropbox/Public/Olivier/Projects/scRNAseq-Glioma/data/velocyto"
os.chdir(path) # change current path
print(os.getcwd())
# Out:
# /Users/yah2014/Dropbox/Public/Olivier/Projects/scRNAseq-Glioma/data/velocyto

# %% [markdown]
# List all filer folder's names.

# %%
file_folders=os.listdir(os.getcwd())  # list files
print(file_folders)
groups=['PM1005','PM1568','PM1415','PM1559','PM1258']
# Out:
# ['PM1005_merged.loom', 'PM1559_merged.loom', 'PM1568_merged.loom', 'PM1415_merge.loom', 'PM1258_merged.loom']

# %% [markdown]
# List all paths and .loom files

# %% [markdown]
# ### Merging multiple samples/lanes in a single file
# Let’s start with loading the content of the .loom file into an interactive session of python.

# %% [markdown]
# ## Inspect the merged loom file

# %% [markdown]
# Let’s start with loading the content of the .loom file into an interactive session of python.“VelocytoLoom” object supports some ready-made plotting functions. For example, one of the first checks is spliced/unspliced fractions of the dataset can be done by calling:

# %%
import velocyto as vcy
vlm1 = vcy.VelocytoLoom("PM1005_merged.loom")
vlm1.plot_fractions()

# %%
vlm2 = vcy.VelocytoLoom("PM1568_merged.loom")
vlm2.plot_fractions()

# %%
vlm3 = vcy.VelocytoLoom("PM1415_merged.loom")
vlm3.plot_fractions()

# %%
vlm4 = vcy.VelocytoLoom("PM1559_merged.loom")
vlm4.plot_fractions()

# %%
vlm5 = vcy.VelocytoLoom("PM1258_merged.loom")
vlm5.plot_fractions()
